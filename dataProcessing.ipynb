# %%
import pandas as pd

# %%
movies = pd.read_csv('TMDB_movie_dataset_v11.csv')

# %%
movies
# Out:
#               id            title  vote_average  vote_count    status  \
# 0          27205        Inception         8.364       34495  Released
# 1         157336     Interstellar         8.417       32571  Released
# 2            155  The Dark Knight         8.512       30619  Released
# 3          19995           Avatar         7.573       29815  Released
# 4          24428     The Avengers         7.710       29166  Released
# ...          ...              ...           ...         ...       ...
# 1141334   735373    Fire! Hendrix         0.000           0  Released
# 1141335   735374       Audionomie         0.000           0  Released
# 1141336   735375     Pleasure Fix         0.000           0  Released
# 1141337   735377        Mambo Man         0.000           0  Released
# 1141338  1396654        Cock Time         0.000           0  Released
#
#         release_date     revenue  runtime  adult  \
# 0         2010-07-15   825532764      148  False
# ...

# %%
new_data = movies[['imdb_id', 'title', 'genres', 'keywords']]

# %%
new_data
# Out:
#             imdb_id            title  \
# 0         tt1375666        Inception
# 1         tt0816692     Interstellar
# 2         tt0468569  The Dark Knight
# 3         tt0499549           Avatar
# 4         tt0848228     The Avengers
# ...             ...              ...
# 1141334         NaN    Fire! Hendrix
# 1141335  tt12036232       Audionomie
# 1141336  tt14549914     Pleasure Fix
# 1141337  tt12600214        Mambo Man
# 1141338         NaN        Cock Time
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1141334                                          NaN
# 1141335                                       Horror
# ...

# %%
new_data.isnull().sum()
# Out:
# imdb_id     537478
# title           13
# genres      458138
# keywords    832675
# dtype: int64

# %%
new_data = new_data.dropna(subset=['imdb_id'])

# %%
new_data['genres'] = new_data['genres'].fillna('Undefined')
new_data['keywords'] = new_data['keywords'].fillna('Undefined')
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_18720\1884549201.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['genres'] = new_data['genres'].fillna('Undefined')
# C:\Users\rahul\AppData\Local\Temp\ipykernel_18720\1884549201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['keywords'] = new_data['keywords'].fillna('Undefined')

# %%
movies.columns
# Out:
# Index(['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date',
#        'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'tagline', 'genres',
#        'production_companies', 'production_countries', 'spoken_languages',
#        'keywords'],
#       dtype='object')

# %%
ratings = movies[['imdb_id', 'vote_average']]

# %%
ratings.insert(0, 'userId', '')

# %%
ratings
# Out:
#         userId     imdb_id  vote_average
# 0                tt1375666         8.364
# 1                tt0816692         8.417
# 2                tt0468569         8.512
# 3                tt0499549         7.573
# 4                tt0848228         7.710
# ...        ...         ...           ...
# 1141334                NaN         0.000
# 1141335         tt12036232         0.000
# 1141336         tt14549914         0.000
# 1141337         tt12600214         0.000
# 1141338                NaN         0.000
#
# [1141339 rows x 3 columns]

# %%
ratings = ratings.dropna(subset=['imdb_id'])

# %%
import numpy as np

# Generate random user IDs between 1 and 1000 for all rows
np.random.seed(42)  # for reproducibility
ratings['userId'] = np.random.randint(1, 1001, size=len(ratings))
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_18720\1796644822.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ratings['userId'] = np.random.randint(1, 1001, size=len(ratings))

# %%
ratings.isnull().sum()
# Out:
# userId          0
# imdb_id         0
# vote_average    0
# dtype: int64

# %%
new_data = new_data.rename(columns={'imdb_id': 'movieId'})
ratings = ratings.rename(columns={'imdb_id': 'movieId'})

# %%
new_data.head()
# Out:
#      movieId            title                                       genres  \
# 0  tt1375666        Inception           Action, Science Fiction, Adventure
# 1  tt0816692     Interstellar            Adventure, Drama, Science Fiction
# 2  tt0468569  The Dark Knight               Drama, Action, Crime, Thriller
# 3  tt0499549           Avatar  Action, Adventure, Fantasy, Science Fiction
# 4  tt0848228     The Avengers           Science Fiction, Action, Adventure
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...

# %%
new_data_sample = new_data.sample(n=20000, random_state=42)
ratings_sample = ratings.sample(n=20000, random_state=42)

# %%
new_data_sample
# Out:
#            movieId                                    title  \
# 878076   tt0892272                        Casino: The Story
# 679554  tt21382166                                   Mirada
# 583914  tt31823556                                 Stick-Up
# 784263   tt7725546                            Contingencies
# 62657    tt3733618                                    Trace
# ...            ...                                      ...
# 100062   tt7745044                               Homo Novus
# 777660   tt3240226               Ciné regards: Jacques Tati
# 31840    tt1359421                 The Wedding Photographer
# 33268    tt0067467                                Red Psalm
# 134343   tt6255780  The Little Cars 2: Rodopolis Adventures
#
#                              genres  \
# 878076                  Documentary
# 679554                    Undefined
# 583914                    Undefined
# 784263                        Drama
# 62657                        Horror
# ...

# %%
new_data.to_csv('movies.csv', index=False)
ratings.to_csv('ratings.csv', index=False)
